# %% [markdown]
# ## Trafic Sign Detection

# %% [markdown]
# ### Notebook created to predict accuracy in the detection of traffic signs quantifying the results.

# %% [markdown]
# #### The dataset was collected from this part of the model.

# %%
from IPython.display import Image
Image(url='gif.gif')
# Out:
# <img src="gif.gif"/>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    accuracy  object      coordx      coordy      coordz      coordw
# 0  0.000000      11  590.012817  245.008469  600.899597  268.442474
# 1  0.635609      11  606.012817  236.008469  639.899597  271.442474
# 2  0.903058      11  631.614502  230.327164  674.853577  275.513306
# 3  0.979369      11  637.846497  228.060928  679.428589  271.221344
# 4  0.990305      11  642.015076  225.625229  684.618835  272.191711

# %%
df.shape
# Out:
# (455, 6)

# %%
df['accuracy'].hist()

# %%
df.plot.area(alpha=0.4)

# %%
df['accuracy'].plot.kde()

# %%
df['accuracy']
# Out:
# 0      0.000000
# 1      0.635609
# 2      0.903058
# 3      0.979369
# 4      0.990305
#          ...
# 450    0.990254
# 451    0.979651
# 452    0.988326
# 453    0.986981
# 454    0.996056
# Name: accuracy, Length: 455, dtype: float64

# %%
import seaborn as sns
sns.pairplot(df[1:])

# %%
df.idxmin()
# Out:
# accuracy      0
# object        0
# coordx        0
# coordy      454
# coordz        0
# coordw        0
# dtype: int64

# %%
df.idxmax()
# Out:
# accuracy     17
# object        0
# coordx      454
# coordy        0
# coordz      451
# coordw      454
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 455 entries, 0 to 454
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   accuracy  455 non-null    float64
#  1   object    455 non-null    int64
#  2   coordx    455 non-null    float64
#  3   coordy    455 non-null    float64
#  4   coordz    455 non-null    float64
#  5   coordw    455 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 21.5 KB

# %%
df['accuracy']
# Out:
# 0      0.000000
# 1      0.635609
# 2      0.903058
# 3      0.979369
# 4      0.990305
#          ...
# 450    0.990254
# 451    0.979651
# 452    0.988326
# 453    0.986981
# 454    0.996056
# Name: accuracy, Length: 455, dtype: float64

# %%
df['coordx']
# Out:
# 0      590.012817
# 1      606.012817
# 2      631.614502
# 3      637.846497
# 4      642.015076
#           ...
# 450    859.646545
# 451    865.682434
# 452    879.106201
# 453    890.945007
# 454    900.257690
# Name: coordx, Length: 455, dtype: float64

# %%
df.plot.density()
